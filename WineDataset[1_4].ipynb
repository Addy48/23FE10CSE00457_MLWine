# %% [markdown]
# <a href="https://colab.research.google.com/github/Addy48/23FE10CSE00457_MLWine/blob/main/WineDataset%5B1_4%5D.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# LAB 1 Experiment

# %%
import numpy as np
import pandas as pd

# %%
white_df = pd.read_csv('/content/winequality-white.csv', sep=';')
white_df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.0              0.27         0.36            20.7      0.045
# 1            6.3              0.30         0.34             1.6      0.049
# 2            8.1              0.28         0.40             6.9      0.050
# 3            7.2              0.23         0.32             8.5      0.058
# 4            7.2              0.23         0.32             8.5      0.058
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 45.0                 170.0   1.0010  3.00       0.45
# 1                 14.0                 132.0   0.9940  3.30       0.49
# 2                 30.0                  97.0   0.9951  3.26       0.44
# 3                 47.0                 186.0   0.9956  3.19       0.40
# 4                 47.0                 186.0   0.9956  3.19       0.40
#
#    alcohol  quality
# 0      8.8        6
# 1      9.5        6
# 2     10.1        6
# ...

# %%
print("Shape:", white_df.shape)
print("\nColumns:")
print(white_df.columns)
# Out:
# Shape: (4898, 12)
#
# Columns:
# Index(['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar',
#        'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density',
#        'pH', 'sulphates', 'alcohol', 'quality'],
#       dtype='object')

# %%
white_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4898 entries, 0 to 4897
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         4898 non-null   float64
#  1   volatile acidity      4898 non-null   float64
#  2   citric acid           4898 non-null   float64
#  3   residual sugar        4898 non-null   float64
#  4   chlorides             4898 non-null   float64
#  5   free sulfur dioxide   4898 non-null   float64
#  6   total sulfur dioxide  4898 non-null   float64
#  7   density               4898 non-null   float64
#  8   pH                    4898 non-null   float64
#  9   sulphates             4898 non-null   float64
#  10  alcohol               4898 non-null   float64
#  11  quality               4898 non-null   int64
# dtypes: float64(11), int64(1)
# memory usage: 459.3 KB

# %%
white_df.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    4898.000000       4898.000000  4898.000000     4898.000000
# mean        6.854788          0.278241     0.334192        6.391415
# std         0.843868          0.100795     0.121020        5.072058
# min         3.800000          0.080000     0.000000        0.600000
# 25%         6.300000          0.210000     0.270000        1.700000
# 50%         6.800000          0.260000     0.320000        5.200000
# 75%         7.300000          0.320000     0.390000        9.900000
# max        14.200000          1.100000     1.660000       65.800000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  4898.000000          4898.000000           4898.000000  4898.000000
# mean      0.045772            35.308085            138.360657     0.994027
# std       0.021848            17.007137             42.498065     0.002991
# ...

# %%
alcohol = white_df['alcohol'].values

print("Mean Alcohol:", np.mean(alcohol))
print("Max Alcohol:", np.max(alcohol))
print("Min Alcohol:", np.min(alcohol))
# Out:
# Mean Alcohol: 10.514267047774602
# Max Alcohol: 14.2
# Min Alcohol: 8.0

# %% [markdown]
# LAB 2 Experiment

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import StandardScaler

# %%
white_df.isnull().sum()
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64

# %%
X = white_df.drop('quality', axis=1)
y = white_df['quality']

# %%
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

X_scaled_df = pd.DataFrame(X_scaled, columns=X.columns)
X_scaled_df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0       0.172097         -0.081770     0.213280        2.821349  -0.035355
# 1      -0.657501          0.215896     0.048001       -0.944765   0.147747
# 2       1.475751          0.017452     0.543838        0.100282   0.193523
# 3       0.409125         -0.478657    -0.117278        0.415768   0.559727
# 4       0.409125         -0.478657    -0.117278        0.415768   0.559727
#
#    free sulfur dioxide  total sulfur dioxide   density        pH  sulphates  \
# 0             0.569932              0.744565  2.331512 -1.246921  -0.349184
# 1            -1.253019             -0.149685 -0.009154  0.740029   0.001342
# 2            -0.312141             -0.973336  0.358665  0.475102  -0.436816
# 3             0.687541              1.121091  0.525855  0.011480  -0.787342
# 4             0.687541              1.121091  0.525855  0.011480  -0.787342
#
#     alcohol
# 0 -1.393152
# 1 -0.824276
# 2 -0.336667
# ...

# %%
white_df.hist(figsize=(15,10))
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(12,6))
sns.boxplot(data=white_df)
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(12,8))
sns.heatmap(white_df.corr(), annot=False, cmap='coolwarm')
plt.title("Correlation Heatmap")
plt.show()

# %% [markdown]
# LAB 3 Experiment

# %%
stats_df = pd.DataFrame({
    'Mean': white_df.mean(),
    'Median': white_df.median(),
    'Variance': white_df.var(),
    'Std Dev': white_df.std()
})

stats_df
# Out:
#                             Mean     Median     Variance    Std Dev
# fixed acidity           6.854788    6.80000     0.712114   0.843868
# volatile acidity        0.278241    0.26000     0.010160   0.100795
# citric acid             0.334192    0.32000     0.014646   0.121020
# residual sugar          6.391415    5.20000    25.725770   5.072058
# chlorides               0.045772    0.04300     0.000477   0.021848
# free sulfur dioxide    35.308085   34.00000   289.242720  17.007137
# total sulfur dioxide  138.360657  134.00000  1806.085491  42.498065
# density                 0.994027    0.99374     0.000009   0.002991
# pH                      3.188267    3.18000     0.022801   0.151001
# sulphates               0.489847    0.47000     0.013025   0.114126
# alcohol                10.514267   10.40000     1.514427   1.230621
# quality                 5.877909    6.00000     0.784356   0.885639

# %%
skew_kurt_df = pd.DataFrame({
    'Skewness': white_df.skew(),
    'Kurtosis': white_df.kurtosis()
})

skew_kurt_df
# Out:
#                       Skewness   Kurtosis
# fixed acidity         0.647751   2.172178
# volatile acidity      1.576980   5.091626
# citric acid           1.281920   6.174901
# residual sugar        1.077094   3.469820
# chlorides             5.023331  37.564600
# free sulfur dioxide   1.406745  11.466342
# total sulfur dioxide  0.390710   0.571853
# density               0.977773   9.793807
# pH                    0.457783   0.530775
# sulphates             0.977194   1.590930
# alcohol               0.487342  -0.698425
# quality               0.155796   0.216526

# %%
corr_with_quality = white_df.corr()['quality'].sort_values(ascending=False)
corr_with_quality
# Out:
# quality                 1.000000
# alcohol                 0.435575
# pH                      0.099427
# sulphates               0.053678
# free sulfur dioxide     0.008158
# citric acid            -0.009209
# residual sugar         -0.097577
# fixed acidity          -0.113663
# total sulfur dioxide   -0.174737
# volatile acidity       -0.194723
# chlorides              -0.209934
# density                -0.307123
# Name: quality, dtype: float64

# %%
print("Top Positive Correlation Feature:", corr_with_quality.index[1])
print("Top Negative Correlation Feature:", corr_with_quality.index[-1])
# Out:
# Top Positive Correlation Feature: alcohol
# Top Negative Correlation Feature: density

# %% [markdown]
# LAB 4 Expermient

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import StandardScaler

# %%
df = pd.read_csv('/winequality-white.csv', sep=';')
df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.0              0.27         0.36            20.7      0.045
# 1            6.3              0.30         0.34             1.6      0.049
# 2            8.1              0.28         0.40             6.9      0.050
# 3            7.2              0.23         0.32             8.5      0.058
# 4            7.2              0.23         0.32             8.5      0.058
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 45.0                 170.0   1.0010  3.00       0.45
# 1                 14.0                 132.0   0.9940  3.30       0.49
# 2                 30.0                  97.0   0.9951  3.26       0.44
# 3                 47.0                 186.0   0.9956  3.19       0.40
# 4                 47.0                 186.0   0.9956  3.19       0.40
#
#    alcohol  quality
# 0      8.8        6
# 1      9.5        6
# 2     10.1        6
# ...

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.dtypes
# Out:
# fixed acidity           float64
# volatile acidity        float64
# citric acid             float64
# residual sugar          float64
# chlorides               float64
# free sulfur dioxide     float64
# total sulfur dioxide    float64
# density                 float64
# pH                      float64
# sulphates               float64
# alcohol                 float64
# quality                   int64
# dtype: object

# %%
non_numeric_cols = df.select_dtypes(include=['object']).columns
print("Non-numeric columns:", list(non_numeric_cols))

df = df.drop(columns=non_numeric_cols)
# Out:
# Non-numeric columns: []

# %%
X = df.drop('quality', axis=1)
y = df['quality']


scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)


X_scaled = pd.DataFrame(X_scaled, columns=X.columns)


X_train, X_test, y_train, y_test = train_test_split(
    X_scaled, y, test_size=0.2, random_state=42
)

# %%
lr_model = LinearRegression()
lr_model.fit(X_train, y_train)


intercept = lr_model.intercept_
coefficients = lr_model.coef_

# %%
coef_df = pd.DataFrame({
    'Feature': X.columns,
    'Coefficient': coefficients
})


coef_df = coef_df.sort_values(by='Coefficient', ascending=False)


intercept_df = pd.DataFrame({
    'Feature': ['Intercept'],
    'Coefficient': [intercept]
})

final_coeff_df = pd.concat([intercept_df, coef_df], ignore_index=True)
final_coeff_df
# Out:
#                  Feature  Coefficient
# 0              Intercept     5.875730
# 1         residual sugar     0.361294
# 2                alcohol     0.281794
# 3                     pH     0.090697
# 4    free sulfur dioxide     0.087058
# 5              sulphates     0.074068
# 6          fixed acidity     0.038736
# 7              chlorides    -0.000578
# 8            citric acid    -0.007418
# 9   total sulfur dioxide    -0.010290
# 10      volatile acidity    -0.192990
# 11               density    -0.371624
